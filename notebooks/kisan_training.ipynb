# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
import os

data_dir = "/kaggle/input/plantvillage-dataset/plantvillage dataset/color"
classes = sorted(os.listdir(data_dir))

print(f"Total classes  : {len(classes)}")
print(f"Total images   : {sum(len(os.listdir(os.path.join(data_dir, c))) for c in classes):,}")
print(f"\nFirst 5 classes:")
for c in classes[:5]:
    count = len(os.listdir(os.path.join(data_dir, c)))
    print(f"  {c} — {count} images")

# %%
import os

# Find the actual path
for root, dirs, files in os.walk("/kaggle/input"):
    level = root.replace("/kaggle/input", "").count(os.sep)
    if level < 3:
        print(root)

# %%
import os

# Find the actual path
for root, dirs, files in os.walk("/kaggle/input"):
    level = root.replace("/kaggle/input", "").count(os.sep)
    if level < 3:
        print(root)

# %%
import os
for root, dirs, files in os.walk("/kaggle/input"):
    level = root.replace("/kaggle/input", "").count(os.sep)
    if level < 3:
        print(root)

# %%
import os
for root, dirs, files in os.walk("/kaggle/input/datasets/abdallahalidev"):
    level = root.count(os.sep)
    indent = " " * 2 * level
    print(f"{indent}{os.path.basename(root)}/")
    if level > 5:
        break

# %%
import os
for root, dirs, files in os.walk("/kaggle/input"):
    level = root.replace("/kaggle/input", "").count(os.sep)
    if level < 4:
        print(root)

# %%
import os
for root, dirs, files in os.walk("/kaggle/input/datasets/abdallahalidev"):
    print(root)

# %%
import os

# Install kaggle
os.system("pip install kaggle -q")

# Create kaggle config directory
os.makedirs("/root/.kaggle", exist_ok=True)

# Download dataset directly
os.system("kaggle datasets download -d abdallahalidev/plantvillage-dataset --path /kaggle/working/")

print("Download started... this takes 2-3 minutes")

# %%
# !pip install -q kaggle
# !kaggle datasets download -d vipoooool/new-plant-diseases-dataset --path /kaggle/working/
# !unzip -q /kaggle/working/new-plant-diseases-dataset.zip -d /kaggle/working/data/
# !ls /kaggle/working/data/

# %%
# !pip install -q kaggle
# !kaggle datasets download -d vipoooool/new-plant-diseases-dataset --path /kaggle/working/
# !unzip -q /kaggle/working/new-plant-diseases-dataset.zip -d /kaggle/working/data/
# !ls /kaggle/working/data/

# %%
# !kaggle datasets download -d abdallahalidev/plantvillage-dataset --path /kaggle/working/
# !unzip -q /kaggle/working/plantvillage-dataset.zip -d /kaggle/working/data/
# !ls /kaggle/working/data/

# %%
import os

data_dir = "/kaggle/working/data/plantvillage dataset/color"
classes = sorted(os.listdir(data_dir))

print(f"Total classes : {len(classes)}")
print(f"Total images  : {sum(len(os.listdir(os.path.join(data_dir, c))) for c in classes):,}")
print(f"\nAll 38 classes:")
for i, c in enumerate(classes, 1):
    count = len(os.listdir(os.path.join(data_dir, c)))
    print(f"  {i:2}. {c} — {count} images")

# %%
import matplotlib.pyplot as plt
import random
from PIL import Image

# ── Plot 1: Sample images from 10 random classes ──────────────────────────────
fig, axes = plt.subplots(2, 5, figsize=(18, 7))
sample_classes = random.sample(classes, 10)

for ax, cls in zip(axes.flat, sample_classes):
    img_path = os.path.join(data_dir, cls, 
                os.listdir(os.path.join(data_dir, cls))[0])
    img = Image.open(img_path)
    ax.imshow(img)
    ax.set_title(cls.split("___")[1].replace("_", " ")[:20], fontsize=8)
    ax.axis("off")

plt.suptitle("Kisan AI — Sample Leaf Images", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig("sample_images.png", dpi=120)
plt.show()
print("Plot 1 done ✓")

# ── Plot 2: Class distribution bar chart ──────────────────────────────────────
counts = {c: len(os.listdir(os.path.join(data_dir, c))) for c in classes}
short_names = [c.split("___")[1].replace("_", " ")[:22] for c in classes]

plt.figure(figsize=(16, 7))
bars = plt.barh(short_names, list(counts.values()), color='#2d9e6b')
plt.xlabel("Number of images")
plt.title("Kisan AI — Images per class", fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig("class_distribution.png", dpi=120)
plt.show()
print("Plot 2 done ✓")

# ── Key stats ─────────────────────────────────────────────────────────────────
count_vals = list(counts.values())
print(f"\nDataset stats:")
print(f"  Total images : {sum(count_vals):,}")
print(f"  Most images  : {max(counts, key=counts.get)} — {max(count_vals)}")
print(f"  Least images : {min(counts, key=counts.get)} — {min(count_vals)}")
print(f"  Average/class: {sum(count_vals)//len(count_vals)}")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models

# ── Check GPU ─────────────────────────────────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
if device.type == "cuda":
    print(f"GPU: {torch.cuda.get_device_name(0)}")
else:
    print("No GPU — go to Settings (top right) → Accelerator → GPU T4 x2")

# ── Transforms ────────────────────────────────────────────────────────────────
train_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.3, contrast=0.3),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])
val_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

# ── Dataset ───────────────────────────────────────────────────────────────────
full_dataset = datasets.ImageFolder(data_dir, transform=train_tf)
n = len(full_dataset)
train_n = int(0.8 * n)
val_n   = int(0.1 * n)
test_n  = n - train_n - val_n

generator = torch.Generator().manual_seed(42)
train_set, val_set, test_set = random_split(
    full_dataset, [train_n, val_n, test_n], generator=generator)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True,  num_workers=2)
val_loader   = DataLoader(val_set,   batch_size=32, shuffle=False, num_workers=2)

print(f"\nTrain : {len(train_set):,} images")
print(f"Val   : {len(val_set):,} images")
print(f"Test  : {len(test_set):,} images")
print(f"Classes: {len(full_dataset.classes)}")

# ── Model ─────────────────────────────────────────────────────────────────────
model = models.efficientnet_b0(weights='IMAGENET1K_V1')
for param in model.parameters():
    param.requires_grad = False

in_features = model.classifier[1].in_features
model.classifier = nn.Sequential(
    nn.Dropout(p=0.3),
    nn.Linear(in_features, len(full_dataset.classes))
)
model = model.to(device)
print(f"\nModel ready — EfficientNetB0")
print(f"Trainable params: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")

# %%
import os

data_dir = "/kaggle/working/data/plantvillage dataset/color"
classes = sorted(os.listdir(data_dir))

print(f"Total classes : {len(classes)}")
print(f"Total images  : {sum(len(os.listdir(os.path.join(data_dir, c))) for c in classes):,}")
print(f"\nAll 38 classes:")
for i, c in enumerate(classes, 1):
    count = len(os.listdir(os.path.join(data_dir, c)))
    print(f"  {i:2}. {c} — {count} images")

# %%
import os

# !kaggle datasets download -d abdallahalidev/plantvillage-dataset --path /kaggle/working/
# !unzip -q /kaggle/working/plantvillage-dataset.zip -d /kaggle/working/data/
print("Done!")

# %%
# !kaggle datasets download -d abdallahalidev/plantvillage-dataset --path /kaggle/working/
# !unzip -q /kaggle/working/plantvillage-dataset.zip -d /kaggle/working/data/
print("Done!")

# %%
import os

data_dir = "/kaggle/working/data/plantvillage dataset/color"
classes = sorted(os.listdir(data_dir))
print(f"Total classes : {len(classes)}")
print(f"Total images  : {sum(len(os.listdir(os.path.join(data_dir, c))) for c in classes):,}")

# %%
import os

# Download dataset
os.system("kaggle datasets download -d abdallahalidev/plantvillage-dataset --path /kaggle/working/")
os.system("unzip -q /kaggle/working/plantvillage-dataset.zip -d /kaggle/working/data/")

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
print(f"GPU: {torch.cuda.get_device_name(0)}")

data_dir = "/kaggle/working/data/plantvillage dataset/color"

train_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.3, contrast=0.3),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])
val_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

full_dataset = datasets.ImageFolder(data_dir, transform=train_tf)
n = len(full_dataset)
train_n, val_n = int(0.8*n), int(0.1*n)
test_n = n - train_n - val_n

generator = torch.Generator().manual_seed(42)
train_set, val_set, test_set = random_split(full_dataset, [train_n, val_n, test_n], generator=generator)

train_loader = DataLoader(train_set, batch_size=32, shuffle=True,  num_workers=2)
val_loader   = DataLoader(val_set,   batch_size=32, shuffle=False, num_workers=2)

model = models.efficientnet_b0(weights='IMAGENET1K_V1')
for param in model.parameters():
    param.requires_grad = False

in_features = model.classifier[1].in_features
model.classifier = nn.Sequential(
    nn.Dropout(p=0.3),
    nn.Linear(in_features, 38)
)
model = model.to(device)

print(f"Train: {len(train_set):,} | Val: {len(val_set):,} | Test: {len(test_set):,}")
print(f"Model ready on {device} ✓")

# %%
import os
os.system("rm -rf /root/.cache/torch/")
print("Done")

# %%
os.system("pip install -q --force-reinstall torch torchvision")
print("Reinstall done")

# %%
import os, torch, torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models

# Clear any corrupted cache
os.makedirs("/root/.cache/torch/hub/checkpoints", exist_ok=True)

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# Dataset
data_dir = "/kaggle/working/data/plantvillage dataset/color"
train_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.3, contrast=0.3),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])
val_tf = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

full_dataset = datasets.ImageFolder(data_dir, transform=train_tf)
n = len(full_dataset)
train_n, val_n = int(0.8*n), int(0.1*n)
test_n = n - train_n - val_n
generator = torch.Generator().manual_seed(42)
train_set, val_set, test_set = random_split(
    full_dataset, [train_n, val_n, test_n], generator=generator)
train_loader = DataLoader(train_set, batch_size=32, shuffle=True,  num_workers=2)
val_loader   = DataLoader(val_set,   batch_size=32, shuffle=False, num_workers=2)
print(f"Train: {len(train_set):,} | Val: {len(val_set):,} | Test: {len(test_set):,}")

# Save class names
import json
with open("/kaggle/working/class_names.json", "w") as f:
    json.dump(full_dataset.classes, f)
print(f"Classes saved: {len(full_dataset.classes)}")

# Model — download weights fresh
from torchvision.models import EfficientNet_B0_Weights
model = models.efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)
for param in model.parameters():
    param.requires_grad = False
in_features = model.classifier[1].in_features
model.classifier = nn.Sequential(
    nn.Dropout(p=0.3),
    nn.Linear(in_features, 38)
)
model = model.to(device)
print(f"Model ready on {device}")
print("READY TO TRAIN ✓")
# Out:
# Device: cuda
# Train: 43,444 | Val: 5,430 | Test: 5,431
# Classes saved: 38
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 130MB/s]
# Model ready on cuda
# READY TO TRAIN ✓

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
import time

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=1e-3, weight_decay=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=5)

best_val_acc = 0.0

def train_epoch(loader):
    model.train()
    total_loss, correct, total = 0, 0, 0
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad()
        out = model(imgs)
        loss = criterion(out, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        correct += (out.argmax(1) == labels).sum().item()
        total += labels.size(0)
    return total_loss/len(loader), correct/total

@torch.no_grad()
def val_epoch(loader):
    model.eval()
    correct, total = 0, 0
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        out = model(imgs)
        correct += (out.argmax(1) == labels).sum().item()
        total += labels.size(0)
    return correct/total

print("PHASE 1 — Training head only (5 epochs)")
print("="*50)

for epoch in range(5):
    t0 = time.time()
    train_loss, train_acc = train_epoch(train_loader)
    val_acc = val_epoch(val_loader)
    scheduler.step()
    elapsed = time.time() - t0

    print(f"Epoch {epoch+1}/5 | {elapsed:.0f}s | "
          f"loss={train_loss:.4f} | "
          f"train_acc={train_acc:.4f} | "
          f"val_acc={val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "/kaggle/working/best_model.pth")
        print(f"  ✓ Best model saved (val_acc={val_acc:.4f})")

print(f"\nPhase 1 done! Best val_acc={best_val_acc:.4f}")
# Out:
# PHASE 1 — Training head only (5 epochs)
# ...
# Epoch 1/5 | 140s | loss=0.6273 | train_acc=0.8546 | val_acc=0.9383
#   ✓ Best model saved (val_acc=0.9383)
# Epoch 2/5 | 125s | loss=0.2813 | train_acc=0.9194 | val_acc=0.9510
#   ✓ Best model saved (val_acc=0.9510)
# Epoch 3/5 | 125s | loss=0.2403 | train_acc=0.9276 | val_acc=0.9606
#   ✓ Best model saved (val_acc=0.9606)
# Epoch 4/5 | 125s | loss=0.2206 | train_acc=0.9340 | val_acc=0.9621
#   ✓ Best model saved (val_acc=0.9621)
# Epoch 5/5 | 123s | loss=0.2072 | train_acc=0.9376 | val_acc=0.9602
#
# Phase 1 done! Best val_acc=0.9621

# %%
print("PHASE 2 — Full fine-tuning (10 epochs)")
print("="*50)

# Unfreeze all layers
for param in model.parameters():
    param.requires_grad = True

optimizer2 = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)
scheduler2 = CosineAnnealingLR(optimizer2, T_max=10)

for epoch in range(10):
    t0 = time.time()
    train_loss, train_acc = train_epoch(train_loader)
    val_acc = val_epoch(val_loader)
    scheduler2.step()
    elapsed = time.time() - t0

    print(f"Epoch {epoch+6}/15 | {elapsed:.0f}s | "
          f"loss={train_loss:.4f} | "
          f"train_acc={train_acc:.4f} | "
          f"val_acc={val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "/kaggle/working/best_model.pth")
        print(f"  ✓ Best model saved (val_acc={val_acc:.4f})")

print(f"\nTraining complete! Best val_acc={best_val_acc:.4f}")
# Out:
# PHASE 2 — Full fine-tuning (10 epochs)
# ...
# Epoch 6/15 | 240s | loss=0.2120 | train_acc=0.9364 | val_acc=0.9635
#   ✓ Best model saved (val_acc=0.9635)
# /tmp/ipykernel_199/1095922695.py:15: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   scheduler2.step()
# Epoch 7/15 | 240s | loss=0.2105 | train_acc=0.9371 | val_acc=0.9624
# Epoch 8/15 | 239s | loss=0.2083 | train_acc=0.9362 | val_acc=0.9602
# Epoch 9/15 | 239s | loss=0.2087 | train_acc=0.9380 | val_acc=0.9586
# Epoch 10/15 | 239s | loss=0.2070 | train_acc=0.9392 | val_acc=0.9597
# Epoch 11/15 | 238s | loss=0.2085 | train_acc=0.9383 | val_acc=0.9589
# ...

# %%
import os
import shutil

# Check model exists
size = os.path.getsize("/kaggle/working/best_model.pth")
print(f"Model size: {size/1024/1024:.1f} MB")
print(f"Best val accuracy: {best_val_acc*100:.2f}%")

# Copy to output folder so you can download it
shutil.copy("/kaggle/working/best_model.pth", "/kaggle/working/best_model.pth")
shutil.copy("/kaggle/working/class_names.json", "/kaggle/working/class_names.json")

print("\nTo download:")
print("1. Click the folder icon on the left panel")
print("2. Navigate to /kaggle/working/")
print("3. Right click best_model.pth → Download")
print("4. Right click class_names.json → Download")
# Out:
# Model size: 15.8 MB
# Best val accuracy: 96.46%
# ---------------------------------------------------------------------------
# SameFileError                             Traceback (most recent call last)
# /tmp/ipykernel_199/3748184287.py in <cell line: 0>()
#       8
#       9 # Copy to output folder so you can download it
# ---> 10 shutil.copy("/kaggle/working/best_model.pth", "/kaggle/working/best_model.pth")
#      11 shutil.copy("/kaggle/working/class_names.json", "/kaggle/working/class_names.json")
#      12
#
# /usr/lib/python3.12/shutil.py in copy(src, dst, follow_symlinks)
#     433     if os.path.isdir(dst):
#     434         dst = os.path.join(dst, os.path.basename(src))
# --> 435     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     436     copymode(src, dst, follow_symlinks=follow_symlinks)
#     437     return dst
#
# /usr/lib/python3.12/shutil.py in copyfile(src, dst, follow_symlinks)
#     238
#     239     if _samefile(src, dst):
# ...

# %%
from IPython.display import FileLink, display
import os

print(f"best_model.pth  : {os.path.getsize('/kaggle/working/best_model.pth')/1024/1024:.1f} MB")
print(f"class_names.json: {os.path.getsize('/kaggle/working/class_names.json')/1024:.1f} KB")

display(FileLink('/kaggle/working/best_model.pth'))
display(FileLink('/kaggle/working/class_names.json'))
# Out:
# best_model.pth  : 15.8 MB
# class_names.json: 1.1 KB
# /kaggle/working/best_model.pth
# /kaggle/working/class_names.json

# %%
# Install huggingface hub
# !pip install -q huggingface_hub

from huggingface_hub import HfApi, login

# Login with your token
login(token="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")  # paste your token here

api = HfApi()

# Create a model repo on HuggingFace
api.create_repo(
    repo_id="Sudhanshu011/kisan-ai-model",
    repo_type="model",
    exist_ok=True
)

# Upload both files
api.upload_file(
    path_or_fileobj="/kaggle/working/best_model.pth",
    path_in_repo="best_model.pth",
    repo_id="Sudhanshu011/kisan-ai-model"
)
api.upload_file(
    path_or_fileobj="/kaggle/working/class_names.json",
    path_in_repo="class_names.json",
    repo_id="Sudhanshu011/kisan-ai-model"
)

print("✓ Model uploaded to HuggingFace!")
print(f"URL: https://huggingface.co/Sudhanshu011/kisan-ai-model")
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ✓ Model uploaded to HuggingFace!
# URL: https://huggingface.co/Sudhanshu011/kisan-ai-model
